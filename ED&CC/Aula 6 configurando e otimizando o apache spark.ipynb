# %% [markdown]
# ## Bibliotecas

# %%
# instalar as dependências
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
# !tar xf spark-2.4.4-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
# configurar as variáveis de ambiente
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.4-bin-hadoop2.7"

# tornar o pyspark "importável"
import findspark
findspark.init('spark-2.4.4-bin-hadoop2.7')

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as f
from os.path import abspath

# %%
import findspark

findspark.init()

# %%
warehouse_location = abspath('../data/spark-warehouse')

# %% [markdown]
# ## Setup

# %%
spark = (
    SparkSession
    .builder
    .config("spark.driver.memory", '8g')
    .config("spark.sql.warehouse.dir", warehouse_location)
    .enableHiveSupport()
    .getOrCreate()
)

# %%
# df_titles = spark.read.parquet('../data/imdb/title_basics')
df_titles = spark.read.format("parquet").load('/content/gdrive/MyDrive/pyspark/data/imdb/title_basics')

# %% [markdown]
# ## Databases e Catalog

# %% [markdown]
# O catálogo de metadados do Spark pode ser acessado pelo objeto
#
# `SparkSession.catalog`
#
# As principais funcionalidades são:
#
# * `listDatabases()`: lista todas os databases disponíveis;
# * `listTables()`: lista todas as tabelas disponíveis em um determinado database;
# * `listFucntions()`: lista as funções disponíveis em um determinado database;
# * `refreshTable()`: atualiza os metadados de uma determinada tabela
# * `uncacheTable()`: remove uma tabela salva em memória
# * `clearCache()`: remove todas as tabelas salvas em memória

# %%
spark.catalog

# %%
spark.catalog.clearCache()

# %%
spark.catalog.listDatabases()
# Out:
# [Database(name='default', description='Default Hive database', locationUri='file:/data/spark-warehouse')]

# %%
spark.catalog.listTables()
# Out:
# []

# %% [markdown]
# Os databases do Spark são uma ferramenta para organizar tabelas. Eles podem e devem ser vistos como algo muito próximo dos databases de servidores de bancos de dados relacionais. O Spark utiliza por padrão um database chamado default, que serve para criar tabelas, views e realizar consultas caso o usuário não tenha definido o seu próprio. Um ponto importante é que essas estruturas persistem em diferentes sessões: se o usuário mudar de database, todas as tabelas permanecerão no database anterior e vão precisar ser consultadas de maneira diferente.
#
# Existem alguns comandos do SQL importantes na hora de se trabalhar com databases. Else são:
#
# * `SHOW DATABASES`: lista todas os databases disponíveis, de forma análoga ao Catalog ;
# * `CREATE DATABASE <nome_do_db>`: cria um database
# * `USE <nome_do_db>`: define o database como o atual para a realização de queries
#     * **Obs**: ao se mudar de database, é possível acessar tabelas de um database anterior usando o prefixo “nome_do_db.” antes do nome da tabela. Exemplo:
#         ```
#         USE db2
#         SELECT * FROM db1.table
#         ```
# * `SELECT current_database()`: retorna qual o database definido como o atual
# * `DROP DATABASE IF EXISTS <nome_do_db>`: deleta determinado database dentre aqueles que foram definidos. Atenção: nunca delete o database default do Spark.

# %% [markdown]
# ## Tabelas e Views

# %% [markdown]
# ### Tabelas

# %% [markdown]
# * **Managed Tables**: o Spark administra tanto os dados quanto os metadados das tabelas, de forma que operações como DROP TABLE afetam também os dados escritos em disco;
# * **Unmanaged Tables**: o Spark administra somente os metadados da tabela, e os dados escritos em disco não são alterados em nenhum momento

# %%
df_titles.limit(5).toPandas()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
df_titles_sample = df_titles.sample(fraction = 0.1)

# %% [markdown]
# #### Criando Managed Tables

# %%
df_titles_sample.write.saveAsTable("title_basics_managed")

# %% [markdown]
# `CREATE TABLE title_basics_managed (schema)`

# %% [markdown]
# #### Criando Unmanaged Tables

# %%
df_titles_sample.write.option('path', '../data/imdb/title_basics_unmanaged').saveAsTable("title_basics_unmanaged")

# %% [markdown]
# `CREATE EXTERNAL TABLE title_basics_unmanaged (schema)
#  USING parquet OPTIONS (path '../data/imdb/title_basics_unmanaged')`

# %%
spark.catalog.listTables()
# Out:
# [Table(name='title_basics_managed', database='default', description=None, tableType='MANAGED', isTemporary=False),
#  Table(name='title_basics_unmanaged', database='default', description=None, tableType='EXTERNAL', isTemporary=False)]

# %% [markdown]
# ### Views

# %% [markdown]
# #### Criando Views

# %%
df_titles_sample.createOrReplaceTempView('title_basics_view')

# %% [markdown]
# `CREATE OR REPLACE TEMP VIEW AS title_basics_view
#  SELECT * FROM <nome da tabela>`

# %% [markdown]
# #### Criando Views Globais

# %%
df_titles_sample.createOrReplaceGlobalTempView('title_basics_global_view')

# %% [markdown]
# `CREATE OR REPLACE GLOBAL TEMP VIEW AS title_basics_global_view
#  SELECT * FROM <nome da tabela>`

# %%
spark.catalog.listTables()
# Out:
# [Table(name='title_basics_managed', database='default', description=None, tableType='MANAGED', isTemporary=False),
#  Table(name='title_basics_unmanaged', database='default', description=None, tableType='EXTERNAL', isTemporary=False),
#  Table(name='title_basics_view', database=None, description=None, tableType='TEMPORARY', isTemporary=True)]

# %% [markdown]
# #### Deletando Views

# %%
spark.catalog.dropTempView("title_basics_view")

# %%
spark.catalog.dropGlobalTempView("title_basics_global_view")

# %% [markdown]
# ## Acessando a interface de queries

# %%
spark.sql('SHOW DATABASES').toPandas()
# Out:
#   databaseName
# 0      default

# %%
spark.sql("""
CREATE TABLE title_basics_managed 
(tconst STRING, 
 titleType STRING, 
 primaryTitle STRING,
 originalTitle STRING,
 isAdult STRING,
 startYear STRING, 
 endYear STRING,
 runtimeMinutes STRING,
 genres STRING)
""").toPandas()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
spark.sql("""
            INSERT INTO title_basics_managed  SELECT * FROM default.title_basics_managed
          """
).toPandas()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
spark.sql('DROP TABLE title_basics_managed').toPandas()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
spark.sql('USE DEFAULT').toPandas()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
spark.sql('DROP TABLE title_basics_unmanaged').toPandas()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
spark.sql('SHOW TABLES').toPandas()

# %%
df_titles.count()
# Out:
# 8135937

# %% [markdown]
# ## Configurando o Spark

# %% [markdown]
# SparkSession -> spark-submit -> spark-defaults.conf

# %%
import findspark

findspark.init()

# %%
from pyspark.sql import SparkSession
spark = (
    SparkSession
    .builder
    .config('spark.driver.memory', '8g')
    .getOrCreate()
)

# %%
spark.conf.get('spark.driver.memory')
# Out:
# '8g'

# %%
spark.conf.get('spark.sql.shuffle.partitions')
# Out:
# '200'

# %%
spark.conf.set('spark.sql.shuffle.partitions', 100)

# %%
spark.conf.get('spark.sql.shuffle.partitions')
# Out:
# '100'

# %% [markdown]
# * `spark.master`: seleciona o modo de deploy da aplicação Spark. Será tratado em mais detalhes no capítulo seguinte.
# * `spark.driver.memory`: quantidade de memória atribuída para o driver da aplicação.
# * `spark.executor.memory`: quantidade de memória atribuída para cada um dos executores da aplicação.
# * `spark.serializer`: classe utilizada para realizar a serialização de objetos durante a execução. É recomendado utilizar o valor org.apache.spark.serializer.KryoSerializer para ganhar em velocidade de processamento, uma vez que chega a ser até 10x mais rápido que o default.
# * `spark.executor.heartbeatInterval`:  intervalo entre notificações dos executores ao driver. Aumentar esse valor evita que a aplicação sofra com timeouts.
# * `spark.sql.adaptive.enabled`: habilita o Adaptive Query Execution, programa que atualiza o plano de execução durante a execução, a partir de métricas coletadas durante o processo. Ativar essa configuração pode otimizar processamentos significativamente.
# * `spark.sql.shuffle.partitions`: número padrão de partições utilizadas em shuffles de operações de junção (joins) e agregações (agg).
# * `spark.sql.broadcastTimeout`: tempo de timeout em segundos para operações de broadcast join, a serem tratadas no fim do capítulo.

# %% [markdown]
# ### Tornando o Spark Escalável

# %% [markdown]
# * `spark.dynamicAllocation.enabled`: habilita o uso do recurso de dynamic allocation na aplicação.
# * `spark.dynamicAllocation.executorIdleTimeout`: configura o tempo máximo de ociosidade de um executor até que o dynamic allocation o derrube.
# * `spark.dynamicAllocation.initialExecutors`: quantidade inicial de executores na aplicação ao utilizar o dynamic allocation.
# * `spark.dynamicAllocation.maxExecutors`: quantidade mínima de executores na aplicação ao utilizar o dynamic allocation.
# * `spark.dynamicAllocation.minExecutors`: quantidade máxima de executores na aplicação ao utilizar o dynamic allocation.

# %% [markdown]
# ## Persistência de Dados na Memória

# %%
df_titles_sample = df_titles.sample(fraction = 0.1)

# %%
df_titles_sample.limit(5).toPandas()
# Out:
#       tconst titleType                         primaryTitle  \
# 0  tt0000015     short                  Autour d'une cabine
# 1  tt0000020     short                       The Derby 1895
# 2  tt0000028     short                 Fishing for Goldfish
# 3  tt0000036     short                     Awakening of Rip
# 4  tt0000040     short  Barque sortant du port de Trouville
#
#                          originalTitle isAdult startYear endYear  \
# 0                  Autour d'une cabine       0      1894      \N
# 1                       The Derby 1895       0      1895      \N
# 2         La pêche aux poissons rouges       0      1895      \N
# 3                     Awakening of Rip       0      1896      \N
# 4  Barque sortant du port de Trouville       0      1896      \N
#
#   runtimeMinutes                   genres
# 0              2          Animation,Short
# 1              1  Documentary,Short,Sport
# 2              1        Documentary,Short
# 3              0              Drama,Short
# 4             \N        Documentary,Short

# %%
# df_ratings = spark.read.format('parquet').load('../data/imdb/title_ratings')
df_ratings = spark.read.format("parquet").load('/content/gdrive/MyDrive/pyspark/data/imdb/title_ratings')

# %%
df_ratings.limit(5).toPandas()
# Out:
#       tconst averageRating numVotes
# 0  tt0000001           5.7     1759
# 1  tt0000002           6.0      223
# 2  tt0000003           6.5     1516
# 3  tt0000004           6.1      144
# 4  tt0000005           6.2     2330

# %%
int_cols = ['startYear', 'endYear', 'runtimeMinutes', 'isAdult']
for c in int_cols:
    df_titles_sample = (
        df_titles_sample
        .withColumn(c, f.col(c).cast('int'))
    )
# Limpa os Strings
str_cols = ['primaryTitle', 'originalTitle', 'titleType']
for c in str_cols:
    df_titles_sample = (
        df_titles_sample
        .withColumn(c, f.initcap(f.trim(f.col(c))))
    )

# %%
df_join = (
    df_titles_sample
    .replace('\\N', None)
    .withColumn('genres', f.split(f.col('genres'), ','))
    .join(df_ratings, 'tconst', 'left')
)

# %%
df_join.limit(5).toPandas()
# Out:
#       tconst titleType                         primaryTitle  \
# 0  tt0000015     Short                  Autour D'une Cabine
# 1  tt0000020     Short                       The Derby 1895
# 2  tt0000028     Short                 Fishing For Goldfish
# 3  tt0000036     Short                     Awakening Of Rip
# 4  tt0000040     Short  Barque Sortant Du Port De Trouville
#
#                          originalTitle  isAdult  startYear endYear  \
# 0                  Autour D'une Cabine        0       1894    None
# 1                       The Derby 1895        0       1895    None
# 2         La Pêche Aux Poissons Rouges        0       1895    None
# 3                     Awakening Of Rip        0       1896    None
# 4  Barque Sortant Du Port De Trouville        0       1896    None
#
#    runtimeMinutes                       genres averageRating numVotes
# 0             2.0           [Animation, Short]           6.2      914
# 1             1.0  [Documentary, Short, Sport]           5.0      299
# 2             1.0         [Documentary, Short]           5.2      930
# 3             0.0               [Drama, Short]           4.4      542
# 4             NaN         [Documentary, Short]           4.3       47

# %%
df_final = (
    df_join
    .withColumn('genres', f.explode(f.col('genres')))
    .groupBy('titleType')
    .pivot('genres')
    .agg(f.round(f.mean('averageRating'), 2))
    .fillna(0)
)

# %%
df_final.limit(5).toPandas()
# Out:
#    titleType  Action  Adult  Adventure  Animation  Biography  Comedy  Crime  \
# 0    Tvmovie    5.73   5.40       6.03       6.52       6.89    6.47   6.30
# 1   Tvseries    6.97   6.28       7.06       6.76       7.35    6.79   7.00
# 2  Tvepisode    7.47   6.31       7.37       7.31       7.35    7.36   7.56
# 3      Video    6.03   6.50       5.90       6.35       7.24    6.39   5.95
# 4  Videogame    7.01   0.00       7.26       7.24       4.50    7.23   7.34
#
#    Documentary  Drama  ...  News  Reality-TV  Romance  Sci-Fi  Short  Sport  \
# 0         7.11   6.59  ...  6.80        5.91     6.17    5.29   5.80   6.94
# 1         7.30   7.04  ...  6.28        6.12     6.94    6.81   6.89   7.02
# 2         7.51   7.63  ...  6.69        7.03     7.56    7.47   7.04   7.03
# 3         7.09   6.27  ...  5.98        6.82     6.19    6.14   6.77   7.09
# 4         4.50   7.64  ...  0.00        0.00     7.17    7.04   0.00   6.64
#
#    Talk-Show  Thriller   War  Western
# 0       5.00      5.65  7.03     6.50
# 1       6.20      7.27  7.47     7.33
# 2       6.76      7.48  7.79     7.70
# 3       7.29      5.05  7.00     5.99
# 4       0.00      6.39  7.07     7.97
#
# [5 rows x 29 columns]

# %%
df_final.explain('formatted')
# Out:
# == Parsed Logical Plan ==
# 'Project [titleType#259, coalesce(nanvl(Action#380, null), cast(0.0 as double)) AS Action#466, coalesce(nanvl(Adult#381, null), cast(0.0 as double)) AS Adult#467, coalesce(nanvl(Adventure#382, null), cast(0.0 as double)) AS Adventure#468, coalesce(nanvl(Animation#383, null), cast(0.0 as double)) AS Animation#469, coalesce(nanvl(Biography#384, null), cast(0.0 as double)) AS Biography#470, coalesce(nanvl(Comedy#385, null), cast(0.0 as double)) AS Comedy#471, coalesce(nanvl(Crime#386, null), cast(0.0 as double)) AS Crime#472, coalesce(nanvl(Documentary#387, null), cast(0.0 as double)) AS Documentary#473, coalesce(nanvl(Drama#388, null), cast(0.0 as double)) AS Drama#474, coalesce(nanvl(Family#389, null), cast(0.0 as double)) AS Family#475, coalesce(nanvl(Fantasy#390, null), cast(0.0 as double)) AS Fantasy#476, coalesce(nanvl(Film-Noir#391, null), cast(0.0 as double)) AS Film-Noir#477, coalesce(nanvl(Game-Show#392, null), cast(0.0 as double)) AS Game-Show#478, coalesce(nanvl(History#393, null), cast(0.0 as double)) AS History#479, coalesce(nanvl(Horror#394, null), cast(0.0 as double)) AS Horror#480, coalesce(nanvl(Music#395, null), cast(0.0 as double)) AS Music#481, coalesce(nanvl(Musical#396, null), cast(0.0 as double)) AS Musical#482, coalesce(nanvl(Mystery#397, null), cast(0.0 as double)) AS Mystery#483, coalesce(nanvl(News#398, null), cast(0.0 as double)) AS News#484, coalesce(nanvl(Reality-TV#399, null), cast(0.0 as double)) AS Reality-TV#485, coalesce(nanvl(Romance#400, null), cast(0.0 as double)) AS Romance#486, coalesce(nanvl(Sci-Fi#401, null), cast(0.0 as double)) AS Sci-Fi#487, coalesce(nanvl(Short#402, null), cast(0.0 as double)) AS Short#488, ... 5 more fields]
# +- Project [titleType#259, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[0] AS Action#380, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[1] AS Adult#381, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[2] AS Adventure#382, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[3] AS Animation#383, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[4] AS Biography#384, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[5] AS Comedy#385, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[6] AS Crime#386, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[7] AS Documentary#387, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[8] AS Drama#388, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[9] AS Family#389, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[10] AS Fantasy#390, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[11] AS Film-Noir#391, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[12] AS Game-Show#392, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[13] AS History#393, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[14] AS Horror#394, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[15] AS Music#395, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[16] AS Musical#396, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[17] AS Mystery#397, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[18] AS News#398, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[19] AS Reality-TV#399, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[20] AS Romance#400, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[21] AS Sci-Fi#401, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[22] AS Short#402, ... 5 more fields]
#    +- Aggregate [titleType#259], [titleType#259, pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0) AS __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379]
#       +- Aggregate [titleType#259, genres#294], [titleType#259, genres#294, round(avg(cast(averageRating#174 as double)), 2) AS round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321]
#          +- Project [tconst#258, titleType#259, primaryTitle#260, originalTitle#261, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#294, averageRating#174, numVotes#175]
#             +- Generate explode(genres#272), false, [genres#294]
#                +- Project [tconst#258, titleType#259, primaryTitle#260, originalTitle#261, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#272, averageRating#174, numVotes#175]
#                   +- Join LeftOuter, (tconst#258 = tconst#173)
#                      :- Project [tconst#258, titleType#259, primaryTitle#260, originalTitle#261, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, split(genres#262, ,) AS genres#272]
#                      :  +- Project [CASE WHEN (tconst#0 = cast(\N as string)) THEN cast(null as string) ELSE tconst#0 END AS tconst#258, CASE WHEN (titleType#239 = cast(\N as string)) THEN cast(null as string) ELSE titleType#239 END AS titleType#259, CASE WHEN (primaryTitle#219 = cast(\N as string)) THEN cast(null as string) ELSE primaryTitle#219 END AS primaryTitle#260, CASE WHEN (originalTitle#229 = cast(\N as string)) THEN cast(null as string) ELSE originalTitle#229 END AS originalTitle#261, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, CASE WHEN (genres#8 = cast(\N as string)) THEN cast(null as string) ELSE genres#8 END AS genres#262]
#                      :     +- Project [tconst#0, initcap(trim(titleType#1, None)) AS titleType#239, primaryTitle#219, originalTitle#229, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#8]
#                      :        +- Project [tconst#0, titleType#1, primaryTitle#219, initcap(trim(originalTitle#3, None)) AS originalTitle#229, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#8]
#                      :           +- Project [tconst#0, titleType#1, initcap(trim(primaryTitle#2, None)) AS primaryTitle#219, originalTitle#3, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#8]
#                      :              +- Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, cast(isAdult#4 as int) AS isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#8]
#                      :                 +- Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#179, endYear#189, cast(runtimeMinutes#7 as int) AS runtimeMinutes#199, genres#8]
#                      :                    +- Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#179, cast(endYear#6 as int) AS endYear#189, runtimeMinutes#7, genres#8]
#                      :                       +- Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, cast(startYear#5 as int) AS startYear#179, endYear#6, runtimeMinutes#7, genres#8]
#                      :                          +- Sample 0.0, 0.1, false, -7376223269229203101
#                      :                             +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#                      +- Relation[tconst#173,averageRating#174,numVotes#175] parquet
#
# == Analyzed Logical Plan ==
# titleType: string, Action: double, Adult: double, Adventure: double, Animation: double, Biography: double, Comedy: double, Crime: double, Documentary: double, Drama: double, Family: double, Fantasy: double, Film-Noir: double, Game-Show: double, History: double, Horror: double, Music: double, Musical: double, Mystery: double, News: double, Reality-TV: double, Romance: double, Sci-Fi: double, Short: double, ... 5 more fields
# Project [titleType#259, coalesce(nanvl(Action#380, cast(null as double)), cast(0.0 as double)) AS Action#466, coalesce(nanvl(Adult#381, cast(null as double)), cast(0.0 as double)) AS Adult#467, coalesce(nanvl(Adventure#382, cast(null as double)), cast(0.0 as double)) AS Adventure#468, coalesce(nanvl(Animation#383, cast(null as double)), cast(0.0 as double)) AS Animation#469, coalesce(nanvl(Biography#384, cast(null as double)), cast(0.0 as double)) AS Biography#470, coalesce(nanvl(Comedy#385, cast(null as double)), cast(0.0 as double)) AS Comedy#471, coalesce(nanvl(Crime#386, cast(null as double)), cast(0.0 as double)) AS Crime#472, coalesce(nanvl(Documentary#387, cast(null as double)), cast(0.0 as double)) AS Documentary#473, coalesce(nanvl(Drama#388, cast(null as double)), cast(0.0 as double)) AS Drama#474, coalesce(nanvl(Family#389, cast(null as double)), cast(0.0 as double)) AS Family#475, coalesce(nanvl(Fantasy#390, cast(null as double)), cast(0.0 as double)) AS Fantasy#476, coalesce(nanvl(Film-Noir#391, cast(null as double)), cast(0.0 as double)) AS Film-Noir#477, coalesce(nanvl(Game-Show#392, cast(null as double)), cast(0.0 as double)) AS Game-Show#478, coalesce(nanvl(History#393, cast(null as double)), cast(0.0 as double)) AS History#479, coalesce(nanvl(Horror#394, cast(null as double)), cast(0.0 as double)) AS Horror#480, coalesce(nanvl(Music#395, cast(null as double)), cast(0.0 as double)) AS Music#481, coalesce(nanvl(Musical#396, cast(null as double)), cast(0.0 as double)) AS Musical#482, coalesce(nanvl(Mystery#397, cast(null as double)), cast(0.0 as double)) AS Mystery#483, coalesce(nanvl(News#398, cast(null as double)), cast(0.0 as double)) AS News#484, coalesce(nanvl(Reality-TV#399, cast(null as double)), cast(0.0 as double)) AS Reality-TV#485, coalesce(nanvl(Romance#400, cast(null as double)), cast(0.0 as double)) AS Romance#486, coalesce(nanvl(Sci-Fi#401, cast(null as double)), cast(0.0 as double)) AS Sci-Fi#487, coalesce(nanvl(Short#402, cast(null as double)), cast(0.0 as double)) AS Short#488, ... 5 more fields]
# +- Project [titleType#259, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[0] AS Action#380, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[1] AS Adult#381, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[2] AS Adventure#382, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[3] AS Animation#383, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[4] AS Biography#384, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[5] AS Comedy#385, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[6] AS Crime#386, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[7] AS Documentary#387, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[8] AS Drama#388, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[9] AS Family#389, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[10] AS Fantasy#390, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[11] AS Film-Noir#391, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[12] AS Game-Show#392, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[13] AS History#393, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[14] AS Horror#394, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[15] AS Music#395, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[16] AS Musical#396, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[17] AS Mystery#397, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[18] AS News#398, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[19] AS Reality-TV#399, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[20] AS Romance#400, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[21] AS Sci-Fi#401, __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379[22] AS Short#402, ... 5 more fields]
#    +- Aggregate [titleType#259], [titleType#259, pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0) AS __pivot_round(avg(CAST(`averageRating` AS DOUBLE)), 2) AS `round(avg(CAST(``averageRating`` AS DOUBLE)), 2)`#379]
#       +- Aggregate [titleType#259, genres#294], [titleType#259, genres#294, round(avg(cast(averageRating#174 as double)), 2) AS round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321]
#          +- Project [tconst#258, titleType#259, primaryTitle#260, originalTitle#261, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#294, averageRating#174, numVotes#175]
#             +- Generate explode(genres#272), false, [genres#294]
#                +- Project [tconst#258, titleType#259, primaryTitle#260, originalTitle#261, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#272, averageRating#174, numVotes#175]
#                   +- Join LeftOuter, (tconst#258 = tconst#173)
#                      :- Project [tconst#258, titleType#259, primaryTitle#260, originalTitle#261, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, split(genres#262, ,) AS genres#272]
#                      :  +- Project [CASE WHEN (tconst#0 = cast(\N as string)) THEN cast(null as string) ELSE tconst#0 END AS tconst#258, CASE WHEN (titleType#239 = cast(\N as string)) THEN cast(null as string) ELSE titleType#239 END AS titleType#259, CASE WHEN (primaryTitle#219 = cast(\N as string)) THEN cast(null as string) ELSE primaryTitle#219 END AS primaryTitle#260, CASE WHEN (originalTitle#229 = cast(\N as string)) THEN cast(null as string) ELSE originalTitle#229 END AS originalTitle#261, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, CASE WHEN (genres#8 = cast(\N as string)) THEN cast(null as string) ELSE genres#8 END AS genres#262]
#                      :     +- Project [tconst#0, initcap(trim(titleType#1, None)) AS titleType#239, primaryTitle#219, originalTitle#229, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#8]
#                      :        +- Project [tconst#0, titleType#1, primaryTitle#219, initcap(trim(originalTitle#3, None)) AS originalTitle#229, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#8]
#                      :           +- Project [tconst#0, titleType#1, initcap(trim(primaryTitle#2, None)) AS primaryTitle#219, originalTitle#3, isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#8]
#                      :              +- Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, cast(isAdult#4 as int) AS isAdult#209, startYear#179, endYear#189, runtimeMinutes#199, genres#8]
#                      :                 +- Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#179, endYear#189, cast(runtimeMinutes#7 as int) AS runtimeMinutes#199, genres#8]
#                      :                    +- Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#179, cast(endYear#6 as int) AS endYear#189, runtimeMinutes#7, genres#8]
#                      :                       +- Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, cast(startYear#5 as int) AS startYear#179, endYear#6, runtimeMinutes#7, genres#8]
#                      :                          +- Sample 0.0, 0.1, false, -7376223269229203101
#                      :                             +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#                      +- Relation[tconst#173,averageRating#174,numVotes#175] parquet
#
# == Optimized Logical Plan ==
# Aggregate [titleType#259], [titleType#259, coalesce(nanvl(pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)[0], null), 0.0) AS Action#466, coalesce(nanvl(pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)[1], null), 0.0) AS Adult#467, coalesce(nanvl(pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)[2], null), 0.0) AS Adventure#468, coalesce(nanvl(pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)[3], null), 0.0) AS Animation#469, coalesce(nanvl(pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)[4], null), 0.0) AS Biography#470, coalesce(nanvl(pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)[5], null), 0.0) AS Comedy#471, coalesce(nanvl(pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)[6], null), 0.0) AS Crime#472, coalesce(nanvl(pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)[7], null), 0.0) AS Documentary#473, coalesce(nanvl(pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)[8], null), 0.0) AS Drama#474, coalesce(nanvl(pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)[9], null), 0.0) AS Family#475, coalesce(nanvl(pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-N ...
# +- Aggregate [titleType#259, genres#294], [titleType#259, genres#294, round(avg(cast(averageRating#174 as double)), 2) AS round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321]
#    +- Project [titleType#259, genres#294, averageRating#174]
#       +- Generate explode(genres#272), [1], false, [genres#294]
#          +- Project [titleType#259, genres#272, averageRating#174]
#             +- Join LeftOuter, (tconst#258 = tconst#173)
#                :- Project [CASE WHEN (tconst#0 = \N) THEN null ELSE tconst#0 END AS tconst#258, CASE WHEN (initcap(trim(titleType#1, None)) = \N) THEN null ELSE initcap(trim(titleType#1, None)) END AS titleType#259, split(CASE WHEN (genres#8 = \N) THEN null ELSE genres#8 END, ,) AS genres#272]
#                :  +- Sample 0.0, 0.1, false, -7376223269229203101
#                :     +- Project [tconst#0, titleType#1, genres#8]
#                :        +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#                +- Project [tconst#173, averageRating#174]
#                   +- Filter isnotnull(tconst#173)
#                      +- Relation[tconst#173,averageRating#174,numVotes#175] parquet
#
# == Physical Plan ==
# HashAggregate(keys=[titleType#259], functions=[pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)], output=[titleType#259, Action#466, Adult#467, Adventure#468, Animation#469, Biography#470, Comedy#471, Crime#472, Documentary#473, Drama#474, Family#475, Fantasy#476, Film-Noir#477, Game-Show#478, History#479, Horror#480, Music#481, Musical#482, Mystery#483, News#484, Reality-TV#485, Romance#486, Sci-Fi#487, Short#488, ... 5 more fields])
# +- Exchange hashpartitioning(titleType#259, 100)
#    +- HashAggregate(keys=[titleType#259], functions=[partial_pivotfirst(genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321, Action, Adult, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Film-Noir, Game-Show, History, Horror, Music, Musical, Mystery, News, Reality-TV, Romance, Sci-Fi, Short, Sport, Talk-Show, Thriller, War, Western, 0, 0)], output=[titleType#259, Action#350, Adult#351, Adventure#352, Animation#353, Biography#354, Comedy#355, Crime#356, Documentary#357, Drama#358, Family#359, Fantasy#360, Film-Noir#361, Game-Show#362, History#363, Horror#364, Music#365, Musical#366, Mystery#367, News#368, Reality-TV#369, Romance#370, Sci-Fi#371, Short#372, ... 5 more fields])
#       +- *(4) HashAggregate(keys=[titleType#259, genres#294], functions=[avg(cast(averageRating#174 as double))], output=[titleType#259, genres#294, round(avg(CAST(`averageRating` AS DOUBLE)), 2)#321])
#          +- Exchange hashpartitioning(titleType#259, genres#294, 100)
#             +- *(3) HashAggregate(keys=[titleType#259, genres#294], functions=[partial_avg(cast(averageRating#174 as double))], output=[titleType#259, genres#294, sum#581, count#582L])
#                +- *(3) Project [titleType#259, genres#294, averageRating#174]
#                   +- Generate explode(genres#272), [titleType#259, averageRating#174], false, [genres#294]
#                      +- *(2) Project [titleType#259, genres#272, averageRating#174]
#                         +- *(2) BroadcastHashJoin [tconst#258], [tconst#173], LeftOuter, BuildRight
#                            :- *(2) Project [CASE WHEN (tconst#0 = \N) THEN null ELSE tconst#0 END AS tconst#258, CASE WHEN (initcap(trim(titleType#1, None)) = \N) THEN null ELSE initcap(trim(titleType#1, None)) END AS titleType#259, split(CASE WHEN (genres#8 = \N) THEN null ELSE genres#8 END, ,) AS genres#272]
#                            :  +- *(2) Sample 0.0, 0.1, false, -7376223269229203101
#                            :     +- *(2) FileScan parquet [tconst#0,titleType#1,genres#8] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/content/gdrive/MyDrive/pyspark/data/imdb/title_basics], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<tconst:string,titleType:string,genres:string>
#                            +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]))
#                               +- *(1) Project [tconst#173, averageRating#174]
#                                  +- *(1) Filter isnotnull(tconst#173)
#                                     +- *(1) FileScan parquet [tconst#173,averageRating#174] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/content/gdrive/MyDrive/pyspark/data/imdb/title_ratings], PartitionFilters: [], PushedFilters: [IsNotNull(tconst)], ReadSchema: struct<tconst:string,averageRating:string>

# %%
# %%time
df_final.limit(5).toPandas()
# Out:
# CPU times: user 67.4 ms, sys: 9.82 ms, total: 77.3 ms
# Wall time: 8.45 s
#    titleType  Action  Adult  Adventure  Animation  Biography  Comedy  Crime  \
# 0    Tvmovie    5.73   5.40       6.03       6.52       6.89    6.47   6.30
# 1   Tvseries    6.97   6.28       7.06       6.76       7.35    6.79   7.00
# 2  Tvepisode    7.47   6.31       7.37       7.31       7.35    7.36   7.56
# 3      Video    6.03   6.50       5.90       6.35       7.24    6.39   5.95
# 4  Videogame    7.01   0.00       7.26       7.24       4.50    7.23   7.34
#
#    Documentary  Drama  ...  News  Reality-TV  Romance  Sci-Fi  Short  Sport  \
# 0         7.11   6.59  ...  6.80        5.91     6.17    5.29   5.80   6.94
# 1         7.30   7.04  ...  6.28        6.12     6.94    6.81   6.89   7.02
# 2         7.51   7.63  ...  6.69        7.03     7.56    7.47   7.04   7.03
# 3         7.09   6.27  ...  5.98        6.82     6.19    6.14   6.77   7.09
# 4         4.50   7.64  ...  0.00        0.00     7.17    7.04   0.00   6.64
#
#    Talk-Show  Thriller   War  Western
# 0       5.00      5.65  7.03     6.50
# 1       6.20      7.27  7.47     7.33
# 2       6.76      7.48  7.79     7.70
# 3       7.29      5.05  7.00     5.99
# 4       0.00      6.39  7.07     7.97
#
# [5 rows x 29 columns]

# %%
# %%time
df_join.cache()
df_join.count()
# Out:
# CPU times: user 105 ms, sys: 14.4 ms, total: 120 ms
# Wall time: 16.7 s

# %%
df_final.cache()
df_final.count()
# Out:
# 10

# %%
# %%time
df_final.limit(5).toPandas()
# Out:
# CPU times: user 12.2 ms, sys: 647 µs, total: 12.8 ms
# Wall time: 485 ms
#    titleType  Action  Adult  Adventure  Animation  Biography  Comedy  Crime  \
# 0    Tvmovie    5.73   5.40       6.03       6.52       6.89    6.47   6.30
# 1   Tvseries    6.97   6.28       7.06       6.76       7.35    6.79   7.00
# 2  Tvepisode    7.47   6.31       7.37       7.31       7.35    7.36   7.56
# 3      Video    6.03   6.50       5.90       6.35       7.24    6.39   5.95
# 4  Videogame    7.01   0.00       7.26       7.24       4.50    7.23   7.34
#
#    Documentary  Drama  ...  News  Reality-TV  Romance  Sci-Fi  Short  Sport  \
# 0         7.11   6.59  ...  6.80        5.91     6.17    5.29   5.80   6.94
# 1         7.30   7.04  ...  6.28        6.12     6.94    6.81   6.89   7.02
# 2         7.51   7.63  ...  6.69        7.03     7.56    7.47   7.04   7.03
# 3         7.09   6.27  ...  5.98        6.82     6.19    6.14   6.77   7.09
# 4         4.50   7.64  ...  0.00        0.00     7.17    7.04   0.00   6.64
#
#    Talk-Show  Thriller   War  Western
# 0       5.00      5.65  7.03     6.50
# 1       6.20      7.27  7.47     7.33
# 2       6.76      7.48  7.79     7.70
# 3       7.29      5.05  7.00     5.99
# 4       0.00      6.39  7.07     7.97
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Retirando dados da persistência em memória

# %%
df_final.unpersist()
# Out:
# DataFrame[titleType: string, Action: double, Adult: double, Adventure: double, Animation: double, Biography: double, Comedy: double, Crime: double, Documentary: double, Drama: double, Family: double, Fantasy: double, Film-Noir: double, Game-Show: double, History: double, Horror: double, Music: double, Musical: double, Mystery: double, News: double, Reality-TV: double, Romance: double, Sci-Fi: double, Short: double, Sport: double, Talk-Show: double, Thriller: double, War: double, Western: double]

# %%
spark.catalog.clearCache()

# %% [markdown]
# ## Estratégias de Particionamento de Dados

# %% [markdown]
# ### Bucketing

# %%
df_ratings = spark.read.format("parquet").load('/content/gdrive/MyDrive/pyspark/data/imdb/title_ratings')

# %%
df_titles.limit(5).toPandas()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
df_ratings.limit(5).toPandas()
# Out:
#       tconst averageRating numVotes
# 0  tt0000001           5.7     1759
# 1  tt0000002           6.0      223
# 2  tt0000003           6.5     1516
# 3  tt0000004           6.1      144
# 4  tt0000005           6.2     2330

# %%
df_titles.write.format('parquet').bucketBy(5, 'tconst').saveAsTable('title_basics')

# %%
df_ratings.write.format('parquet').bucketBy(5, 'tconst').saveAsTable('title_ratings')

# %%
df_titles_bucket = spark.sql('SELECT * FROM title_basics')

# %%
df_ratings_bucket = spark.sql('SELECT * FROM title_ratings')

# %%
# %%time
df_titles.join(df_ratings, 'tconst').count()
# Out:
# CPU times: user 37.5 ms, sys: 4.28 ms, total: 41.8 ms
# Wall time: 4.12 s
# 1174232

# %%
# %%time
df_titles_bucket.join(df_ratings_bucket, 'tconst').count()
# Out:
# CPU times: user 32.1 ms, sys: 6.22 ms, total: 38.3 ms
# Wall time: 3.73 s
# 1174232

# %% [markdown]
# ### Partiticionando por Colunas

# %%
df_titles.filter('titleType = "short"').explain("formatted")
# Out:
# == Parsed Logical Plan ==
# 'Filter ('titleType = short)
# +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#
# == Analyzed Logical Plan ==
# tconst: string, titleType: string, primaryTitle: string, originalTitle: string, isAdult: string, startYear: string, endYear: string, runtimeMinutes: string, genres: string
# Filter (titleType#1 = short)
# +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#
# == Optimized Logical Plan ==
# Filter (isnotnull(titleType#1) && (titleType#1 = short))
# +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#
# == Physical Plan ==
# *(1) Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genres#8]
# +- *(1) Filter (isnotnull(titleType#1) && (titleType#1 = short))
#    +- *(1) FileScan parquet [tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/content/gdrive/MyDrive/pyspark/data/imdb/title_basics], PartitionFilters: [], PushedFilters: [IsNotNull(titleType), EqualTo(titleType,short)], ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string,originalTitle:string,isAdult:string,sta...

# %%
(
    df_titles
    .write
    .format('parquet')
    .partitionBy('titleType')
    .save('../data/imdb/df_titles_partitioned')
)

# %%
df_titles_partitions = spark.read.parquet('../data/imdb/df_titles_partitioned')

# %%
df_titles_partitions.filter('titleType = "short"').explain("formatted")
# Out:
# == Parsed Logical Plan ==
# 'Filter ('titleType = short)
# +- Relation[tconst#35890,primaryTitle#35891,originalTitle#35892,isAdult#35893,startYear#35894,endYear#35895,runtimeMinutes#35896,genres#35897,titleType#35898] parquet
#
# == Analyzed Logical Plan ==
# tconst: string, primaryTitle: string, originalTitle: string, isAdult: string, startYear: string, endYear: string, runtimeMinutes: string, genres: string, titleType: string
# Filter (titleType#35898 = short)
# +- Relation[tconst#35890,primaryTitle#35891,originalTitle#35892,isAdult#35893,startYear#35894,endYear#35895,runtimeMinutes#35896,genres#35897,titleType#35898] parquet
#
# == Optimized Logical Plan ==
# Filter (isnotnull(titleType#35898) && (titleType#35898 = short))
# +- Relation[tconst#35890,primaryTitle#35891,originalTitle#35892,isAdult#35893,startYear#35894,endYear#35895,runtimeMinutes#35896,genres#35897,titleType#35898] parquet
#
# == Physical Plan ==
# *(1) FileScan parquet [tconst#35890,primaryTitle#35891,originalTitle#35892,isAdult#35893,startYear#35894,endYear#35895,runtimeMinutes#35896,genres#35897,titleType#35898] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/data/imdb/df_titles_partitioned], PartitionCount: 1, PartitionFilters: [isnotnull(titleType#35898), (titleType#35898 = short)], PushedFilters: [], ReadSchema: struct<tconst:string,primaryTitle:string,originalTitle:string,isAdult:string,startYear:string,end...

# %% [markdown]
# ## Reparticionando DataFrames

# %%
df_titles.limit(5).toPandas()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
df_titles.rdd.getNumPartitions()
# Out:
# 3

# %%
df_titles.repartition(5).rdd.getNumPartitions()
# Out:
# 5

# %%
df_titles.coalesce(5).rdd.getNumPartitions()
# Out:
# 3

# %%
df_titles.repartition(5).explain('formatted')
# Out:
# == Parsed Logical Plan ==
# Repartition 5, true
# +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#
# == Analyzed Logical Plan ==
# tconst: string, titleType: string, primaryTitle: string, originalTitle: string, isAdult: string, startYear: string, endYear: string, runtimeMinutes: string, genres: string
# Repartition 5, true
# +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#
# == Optimized Logical Plan ==
# Repartition 5, true
# +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#
# == Physical Plan ==
# Exchange RoundRobinPartitioning(5)
# +- *(1) FileScan parquet [tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/content/gdrive/MyDrive/pyspark/data/imdb/title_basics], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string,originalTitle:string,isAdult:string,sta...

# %% [markdown]
# 1000000 MB / 50 = 20GB/partição

# %% [markdown]
# 1000000 MB / 5 = 200GB/partição

# %%
df_titles.coalesce(5).explain('formatted')
# Out:
# == Parsed Logical Plan ==
# Repartition 5, false
# +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#
# == Analyzed Logical Plan ==
# tconst: string, titleType: string, primaryTitle: string, originalTitle: string, isAdult: string, startYear: string, endYear: string, runtimeMinutes: string, genres: string
# Repartition 5, false
# +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#
# == Optimized Logical Plan ==
# Repartition 5, false
# +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#
# == Physical Plan ==
# Coalesce 5
# +- *(1) FileScan parquet [tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/content/gdrive/MyDrive/pyspark/data/imdb/title_basics], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string,originalTitle:string,isAdult:string,sta...

# %%
df_titles.repartition(50).write.parquet('../data/imdb/df_titles_repartioned')

# %%
df_titles.coalesce(1).write.parquet('../data/imdb/df_titles_coalesced')

# %% [markdown]
# ## Escolhendo o melhor tipo de join

# %% [markdown]
# * **Broadcast Hash Join (BHJ)**: a estratégia consiste em enviar os dados completos para cada um dos executores, de forma que só há necessidade de realizar o shuffle uma vez. O Spark costuma utilizar esse join automaticamente com base em algumas configurações, como o `spark.sql.autoBroadcastJoinThreshold`, que define o tamanho máximo do menor DataFrame para que esse método seja escolhido, mas é sempre interessante analisar cada situação e ter autonomia para indicar o seu uso;
# * **Sort Merge Join (SMJ)**: é o algoritmo padrão do Spark, uma vez que o tamanho dos DataFrames não impacta na viabilidade do algoritmo. Nesse caso, os dados são enviados entre os executores via shuffle e os posteriormente ordenados, para que os dados estejam particionados corretamente e na mesma ordem;
# * **Shuffle Hash Join (SHJ)**: é um algoritmo que também usa shuffles, mas compensa essa operação com o uso de um mapa de hash que exime a necessidade de ordenação dos dados. A única condição é que um dos DataFrames seja significativamente menor do que o outro, mas não tanto quanto o BHJ.

# %%
df_titles.limit(5).toPandas()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
df_ratings.limit(5).toPandas()
# Out:
#       tconst averageRating numVotes
# 0  tt0000001           5.7     1759
# 1  tt0000002           6.0      223
# 2  tt0000003           6.5     1516
# 3  tt0000004           6.1      144
# 4  tt0000005           6.2     2330

# %%
df_titles.join(df_ratings.hint('broadcast'), 'tconst').explain('formatted')
# Out:
# == Parsed Logical Plan ==
# 'Join UsingJoin(Inner,Buffer(tconst))
# :- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
# +- ResolvedHint (broadcast)
#    +- Relation[tconst#35785,averageRating#35786,numVotes#35787] parquet
#
# == Analyzed Logical Plan ==
# tconst: string, titleType: string, primaryTitle: string, originalTitle: string, isAdult: string, startYear: string, endYear: string, runtimeMinutes: string, genres: string, averageRating: string, numVotes: string
# Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genres#8, averageRating#35786, numVotes#35787]
# +- Join Inner, (tconst#0 = tconst#35785)
#    :- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#    +- ResolvedHint (broadcast)
#       +- Relation[tconst#35785,averageRating#35786,numVotes#35787] parquet
#
# == Optimized Logical Plan ==
# Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genres#8, averageRating#35786, numVotes#35787]
# +- Join Inner, (tconst#0 = tconst#35785)
#    :- Filter isnotnull(tconst#0)
#    :  +- Relation[tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] parquet
#    +- ResolvedHint (broadcast)
#       +- Filter isnotnull(tconst#35785)
#          +- Relation[tconst#35785,averageRating#35786,numVotes#35787] parquet
#
# == Physical Plan ==
# *(2) Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genres#8, averageRating#35786, numVotes#35787]
# +- *(2) BroadcastHashJoin [tconst#0], [tconst#35785], Inner, BuildRight
#    :- *(2) Project [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genres#8]
#    :  +- *(2) Filter isnotnull(tconst#0)
#    :     +- *(2) FileScan parquet [tconst#0,titleType#1,primaryTitle#2,originalTitle#3,isAdult#4,startYear#5,endYear#6,runtimeMinutes#7,genres#8] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/content/gdrive/MyDrive/pyspark/data/imdb/title_basics], PartitionFilters: [], PushedFilters: [IsNotNull(tconst)], ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string,originalTitle:string,isAdult:string,sta...
#    +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]))
#       +- *(1) Project [tconst#35785, averageRating#35786, numVotes#35787]
#          +- *(1) Filter isnotnull(tconst#35785)
#             +- *(1) FileScan parquet [tconst#35785,averageRating#35786,numVotes#35787] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/content/gdrive/MyDrive/pyspark/data/imdb/title_ratings], PartitionFilters: [], PushedFilters: [IsNotNull(tconst)], ReadSchema: struct<tconst:string,averageRating:string,numVotes:string>

# %%
import time
import numpy as np

# %% [markdown]
# #### Sort Merge Join

# %%
times = []
for i in range(100):
    start = time.time()
    df_titles.join(df_ratings.hint('merge'), 'tconst').count()
    end = time.time()
    times.append(end - start)

print('Média: ', np.mean(times), '\n',
      'DP: ', np.std(times))
# Out:
# Média:  3.5233033323287963
#  DP:  0.33850659415565226

# %% [markdown]
# #### Shuffled Hash Join

# %%
times = []
for i in range(100):
    start = time.time()
    df_titles.join(df_ratings.hint('shuffle_hash'), 'tconst').count()
    end = time.time()
    times.append(end - start)
print('Média: ', np.mean(times), '\n',
      'DP: ', np.std(times))
# Out:
# Média:  3.400471501350403
#  DP:  0.28339930071275393

# %% [markdown]
# #### Broadcast Join

# %%
times = []
for i in range(100):
    start = time.time()
    df_titles.join(df_ratings.hint('broadcast'), 'tconst').count()
    end = time.time()
    times.append(end - start)
print('Média: ', np.mean(times), '\n',
      'DP: ', np.std(times))
# Out:
# Média:  3.445064709186554
#  DP:  0.3599514298278037
